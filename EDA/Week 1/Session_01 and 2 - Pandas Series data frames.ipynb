# %%
# !pip install pandas

# %% [markdown]
# ## Pandas
#
#     - Python Library
#     - Data manipulation and Analysis (Basic visualization) ->
#     (For high level visualization, use libraries like matplotlib, seaborn)
#     - You can import the data
#         - Reading file like csv, excel, websites
#         - Store it in Dataframes or series
#         - You can explore the data
#         - Can apply mathemtical, statistical methods
#         - ...........

# %%
import pandas as pd

# %% [markdown]
# ## Series

# %%
a = [999, 2342, 1253 ]

# %%
a
# Out:
# [999, 2342, 1253]

# %%
a[0]
# Out:
# 999

# %%
b = pd.Series([ "Ahmad", 1.253, True])

# %%
b
# Out:
# 0    Ahmad
# 1    1.253
# 2     True
# dtype: object

# %% [markdown]
# Series=> Index display along the values + you can change it

# %% [markdown]
# Example
# "Group of Seven or G7"
# political group 7 different countries
#
# Country=>    Canada, France, Germany, Italy, Japan,  UK,  US
# population=> 20.5 ,   30.5,   21.1,   20.7,  30.2,  12.0,  29.8

# %%
population = [20.5 ,   30.5,   21.1,   20.7,  30.2,  12.0,  29.8]

# %%
population
# Out:
# [20.5, 30.5, 21.1, 20.7, 30.2, 12.0, 29.8]

# %%
population = pd.Series([20.5 ,   30.5,   21.1,   20.7,  30.2,  12.0,  29.8])

# %%
population
# Out:
# 0    20.5
# 1    30.5
# 2    21.1
# 3    20.7
# 4    30.2
# 5    12.0
# 6    29.8
# dtype: float64

# %%
#Name

population.name = "G7 Population (in millions)"

# %%
population
# Out:
# 0    20.5
# 1    30.5
# 2    21.1
# 3    20.7
# 4    30.2
# 5    12.0
# 6    29.8
# Name: G7 Population (in millions), dtype: float64

# %%
population.dtype
# Out:
# dtype('float64')

# %%
# Fetch values

population.values
# Out:
# array([20.5, 30.5, 21.1, 20.7, 30.2, 12. , 29.8])

# %% [markdown]
# ### Define index

# %%
population
# Out:
# 0    20.5
# 1    30.5
# 2    21.1
# 3    20.7
# 4    30.2
# 5    12.0
# 6    29.8
# Name: G7 Population (in millions), dtype: float64

# %% [markdown]
# ### Method 1

# %%
population.index  = ["Canada", "France", "Germany", "Italy", "Japan",  "UK",  "US"]

# %%
population
# Out:
# Canada     20.5
# France     30.5
# Germany    21.1
# Italy      20.7
# Japan      30.2
# UK         12.0
# US         29.8
# Name: G7 Population (in millions), dtype: float64

# %%
population['France']
# Out:
# 30.5

# %%
population[1]
# Out:
# 30.5

# %% [markdown]
# ### Method 2

# %%
population = pd.Series([20.5 , 30.5, 21.1,20.7,  30.2,  12.0,  29.8],
                      index =["Canada", "France", "Germany", "Italy", "Japan",  "UK",  "US"],
                      name = "G7 Population (in millions)")

# %%
population
# Out:
# Canada     20.5
# France     30.5
# Germany    21.1
# Italy      20.7
# Japan      30.2
# UK         12.0
# US         29.8
# Name: G7 Population (in millions), dtype: float64

# %% [markdown]
# ### Method 3
#
# Create series using dictionary
# dict = > {key:value} = > series = { index:value}

# %%
population = pd.Series(
                {"Canada":20.5,
                 "France":30.5, 
                 "Germany":21.1, 
                 "Italy":20.7, 
                 "Japan":30.2, 
                 "UK":12.0,  
                 "US":29.8},
    name="G7 Population (in millions)")

# %%
population
# Out:
# Canada     20.5
# France     30.5
# Germany    21.1
# Italy      20.7
# Japan      30.2
# UK         12.0
# US         29.8
# Name: G7 Population (in millions), dtype: float64

# %%
type(population)
# Out:
# pandas.core.series.Series

# %%
help(pd.Series)
# Out:
# Help on class Series in module pandas.core.series:
#
# class Series(pandas.core.base.IndexOpsMixin, pandas.core.generic.NDFrame)
#  |  Series(data=None, index=None, dtype: 'Dtype | None' = None, name=None, copy: 'bool | None' = None, fastpath: 'bool' = False) -> 'None'
#  |
#  |  One-dimensional ndarray with axis labels (including time series).
#  |
#  |  Labels need not be unique but must be a hashable type. The object
#  |  supports both integer- and label-based indexing and provides a host of
#  |  methods for performing operations involving the index. Statistical
#  |  methods from ndarray have been overridden to automatically exclude
#  |  missing data (currently represented as NaN).
#  |
#  |  Operations between Series (+, -, /, \*, \*\*) align values based on their
#  |  associated index values-- they need not be the same length. The result
#  |  index will be the sorted union of the two indexes.
#  |
#  |  Parameters
#  |  ----------
# ...

# %%
population
# Out:
# Canada     20.5
# France     30.5
# Germany    21.1
# Italy      20.7
# Japan      30.2
# UK         12.0
# US         29.8
# Name: G7 Population (in millions), dtype: float64

# %%
population.shape
# Out:
# (7,)

# %% [markdown]
# 7 rows and only  1 column

# %% [markdown]
# ### Create new Series using the existing or predefined one

# %%
population2 = pd.Series(population, index=["Canada","UK","US"])
population2
# Out:
# Canada    20.5
# UK        12.0
# US        29.8
# Name: G7 Population (in millions), dtype: float64

# %% [markdown]
# ### Indexing
# How to fetch the values?

# %%
population
# Out:
# Canada     20.5
# France     30.5
# Germany    21.1
# Italy      20.7
# Japan      30.2
# UK         12.0
# US         29.8
# Name: G7 Population (in millions), dtype: float64

# %%
population.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'UK', 'US'], dtype='object')

# %%
population[::-1]
# Out:
# US         29.8
# UK         12.0
# Japan      30.2
# Italy      20.7
# Germany    21.1
# France     30.5
# Canada     20.5
# Name: G7 Population (in millions), dtype: float64

# %%
population[0]
# Out:
# 20.5

# %%
population["Canada"]
# Out:
# 20.5

# %%
population[["Canada","UK","US","Germany"]]
# Out:
# Canada     20.5
# UK         12.0
# US         29.8
# Germany    21.1
# Name: G7 Population (in millions), dtype: float64

# %% [markdown]
# #### loc and iloc

# %% [markdown]
# population.loc and iloc = > Dataframes
#
# .iloc(row, column)

# %%
population
# Out:
# Canada     20.5
# France     30.5
# Germany    21.1
# Italy      20.7
# Japan      30.2
# UK         12.0
# US         29.8
# Name: G7 Population (in millions), dtype: float64

# %% [markdown]
# iloc works with numeric indexing
# loc works with Textual indexing

# %%
population.iloc[4]
# Out:
# 30.2

# %%
population[0:4]
# Out:
# Canada     20.5
# France     30.5
# Germany    21.1
# Italy      20.7
# Name: G7 Population (in millions), dtype: float64

# %%
population.iloc[0:4]
# Out:
# Canada     20.5
# France     30.5
# Germany    21.1
# Italy      20.7
# Name: G7 Population (in millions), dtype: float64

# %%
population.iloc?

# %% [markdown]
# ## Conditonal selection

# %%
population
# Out:
# Canada     20.5
# France     30.5
# Germany    21.1
# Italy      20.7
# Japan      30.2
# UK         12.0
# US         29.8
# Name: G7 Population (in millions), dtype: float64

# %%
population > 22
# Out:
# Canada     False
# France      True
# Germany    False
# Italy      False
# Japan       True
# UK         False
# US          True
# Name: G7 Population (in millions), dtype: bool

# %%
population[population > 22]
# Out:
# France    30.5
# Japan     30.2
# US        29.8
# Name: G7 Population (in millions), dtype: float64

# %% [markdown]
# ## Operations

# %%
population * 1000000
# Out:
# Canada     20500000.0
# France     30500000.0
# Germany    21100000.0
# Italy      20700000.0
# Japan      30200000.0
# UK         12000000.0
# US         29800000.0
# Name: G7 Population (in millions), dtype: float64

# %%
population + 5
# Out:
# Canada     25.5
# France     35.5
# Germany    26.1
# Italy      25.7
# Japan      35.2
# UK         17.0
# US         34.8
# Name: G7 Population (in millions), dtype: float64

# %%
population.mean()
# Out:
# 23.542857142857144

# %%
population.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 7 entries, Canada to US
# Series name: G7 Population (in millions)
# Non-Null Count  Dtype
# --------------  -----
# 7 non-null      float64
# dtypes: float64(1)
# memory usage: 412.0+ bytes

# %%
population.describe()  #statistical Summary
# Out:
# count     7.000000
# mean     23.542857
# std       6.933219
# min      12.000000
# 25%      20.600000
# 50%      21.100000
# 75%      30.000000
# max      30.500000
# Name: G7 Population (in millions), dtype: float64

# %%
population[["Canada","France"]].mean()
# Out:
# 25.5

# %%
population
# Out:
# Canada     20.5
# France     30.5
# Germany    21.1
# Italy      20.7
# Japan      30.2
# UK         12.0
# US         29.8
# Name: G7 Population (in millions), dtype: float64

# %% [markdown]
# ## modify or update values

# %%
population["Canada"] += 5

# %%
population
# Out:
# Canada     25.5
# France     30.5
# Germany    21.1
# Italy      20.7
# Japan      30.2
# UK         12.0
# US         29.8
# Name: G7 Population (in millions), dtype: float64

# %%
population[::2]
# Out:
# Canada     25.5
# Germany    21.1
# Japan      30.2
# US         29.8
# Name: G7 Population (in millions), dtype: float64

# %% [markdown]
# ## Rename the index

# %%
population = population.rename(index={'Canada': 'United States'})

# %%
population
# Out:
# United States    25.5
# France           30.5
# Germany          21.1
# Italy            20.7
# Japan            30.2
# UK               12.0
# US               29.8
# Name: G7 Population (in millions), dtype: float64

# %% [markdown]
# ## Pandas - DataFrame
#
# The most important data structure of pandas is the DataFrame. It's a tabular structure tightly integrated with Series.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Axis =0 = > Row-Wise Indexing
# Axis = 1 => Column

# %%
import pandas as pd

# %% [markdown]
# DataFrame looks a lot like a table. Creating DataFrames manually can be tedious. 99% of the time you'll be pulling the data from a Database, a csv file or the web. But still, a DataFrame can be created by specifying the columns and values:

# %%
Population = pd.Series([35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523])
Population
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# dtype: float64

# %%
df = pd.DataFrame({
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'Continent': ['America', 'Europe', 'Europe','Europe','Asia','Europe','America']
})

# %%
df
# Out:
#    Population Continent
# 0      35.467   America
# 1      63.951    Europe
# 2      80.940    Europe
# 3      60.665    Europe
# 4     127.061      Asia
# 5      64.511    Europe
# 6     318.523   America

# %%
df = pd.DataFrame({
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
})

# %%
df
# Out:
#    Population       GDP  Surface Area    HDI Continent
# 0      35.467   1785387       9984670  0.913   America
# 1      63.951   2833687        640679  0.888    Europe
# 2      80.940   3874437        357114  0.916    Europe
# 3      60.665   2167744        301336  0.873    Europe
# 4     127.061   4602367        377930  0.891      Asia
# 5      64.511   2950039        242495  0.907    Europe
# 6     318.523  17348075       9525067  0.915   America

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.index  = ["Canada", "France", "Germany", "Italy", "Japan",  "UK",  "US"]

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# UK           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %% [markdown]
# ## Info
#
#
#     - Data structure type
#     - number of Rows
#     - Number of Columns
#     - Each column detail
#         - Column name
#         - value count in each column
#         - Data type of each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to US
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 336.0+ bytes

# %% [markdown]
# ### Describe: Statistical Summary

# %%
df.describe()   #by default it's numeric
# Out:
#        Population           GDP  Surface Area       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429
# std     97.249970  5.494020e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000

# %%
df.describe(include="all")  #for all columns
# Out:
#         Population           GDP  Surface Area       HDI Continent
# count     7.000000  7.000000e+00  7.000000e+00  7.000000         7
# unique         NaN           NaN           NaN       NaN         3
# top            NaN           NaN           NaN       NaN    Europe
# freq           NaN           NaN           NaN       NaN         4
# mean    107.302571  5.080248e+06  3.061327e+06  0.900429       NaN
# std      97.249970  5.494020e+06  4.576187e+06  0.016592       NaN
# min      35.467000  1.785387e+06  2.424950e+05  0.873000       NaN
# 25%      62.308000  2.500716e+06  3.292250e+05  0.889500       NaN
# 50%      64.511000  2.950039e+06  3.779300e+05  0.907000       NaN
# 75%     104.000500  4.238402e+06  5.082873e+06  0.914000       NaN
# max     318.523000  1.734808e+07  9.984670e+06  0.916000       NaN

# %%
df.describe(include="object") #for any specific data type
# Out:
#        Continent
# count          7
# unique         3
# top       Europe
# freq           4

# %%
# finding out the frequency or count of categories 
df["Continent"].value_counts()
# Out:
# Continent
# Europe     4
# America    2
# Asia       1
# Name: count, dtype: int64

# %%
df.values
# Out:
# array([[35.467, 1785387, 9984670, 0.913, 'America'],
#        [63.951, 2833687, 640679, 0.888, 'Europe'],
#        [80.94, 3874437, 357114, 0.916, 'Europe'],
#        [60.665, 2167744, 301336, 0.873, 'Europe'],
#        [127.061, 4602367, 377930, 0.891, 'Asia'],
#        [64.511, 2950039, 242495, 0.907, 'Europe'],
#        [318.523, 17348075, 9525067, 0.915, 'America']], dtype=object)

# %% [markdown]
# index
# columns
# values

# %% [markdown]
# ## Indexing

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# UK           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %% [markdown]
# #### Fetch the data using row index

# %% [markdown]
# Textual Data or Labels or Alphabetic index   = > **loc**
#
# NUmerical indexing = > **iloc**

# %%
df.loc["Canada"]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[0]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# UK           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
df.loc["France","GDP"]  #data_frame.loc[Row , Column]
# Out:
# 2833687

# %%
df.loc["France":"Japan","Population":"Surface Area"]  #data_frame.loc[Row , Column]
# Out:
#          Population      GDP  Surface Area
# France       63.951  2833687        640679
# Germany      80.940  3874437        357114
# Italy        60.665  2167744        301336
# Japan       127.061  4602367        377930

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# UK           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
df.loc[["Germany","UK"] , ["Population", "Surface Area", "Continent"]]
# Out:
#          Population  Surface Area Continent
# Germany      80.940        357114    Europe
# UK           64.511        242495    Europe

# %% [markdown]
# we can fetch
#
#     - single value df.loc[row, column]
#     - Values in a sequence     df.loc[row1:rowN , col1:coln]
#     - specific columns or rows   df.loc[[row1, row5, rowN] ,[col1,col3, col4]]

# %%
df.loc[:, ["Population", "Surface Area", "Continent"]]
# Out:
#          Population  Surface Area Continent
# Canada       35.467       9984670   America
# France       63.951        640679    Europe
# Germany      80.940        357114    Europe
# Italy        60.665        301336    Europe
# Japan       127.061        377930      Asia
# UK           64.511        242495    Europe
# US          318.523       9525067   America

# %%
df.loc["Canada"]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# UK           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
df.iloc[0]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[0,1]
# Out:
# 1785387

# %%
df.iloc[6,4]
# Out:
# 'America'

# %%
df.iloc[1:4, [0,1,4]]
# Out:
#          Population      GDP Continent
# France       63.951  2833687    Europe
# Germany      80.940  3874437    Europe
# Italy        60.665  2167744    Europe

# %%
df.iloc[1:4, [0,1,4]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, France to Italy
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Population  3 non-null      float64
#  1   GDP         3 non-null      int64
#  2   Continent   3 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 96.0+ bytes

# %% [markdown]
# If you are working with numeric indexing(simple list like or iloc) => upper limit will be excluded
#
# Label- wise or loc => upper limit is included

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent
# Canada       35.467   1785387       9984670  0.913   America
# France       63.951   2833687        640679  0.888    Europe
# Germany      80.940   3874437        357114  0.916    Europe
# Italy        60.665   2167744        301336  0.873    Europe
# Japan       127.061   4602367        377930  0.891      Asia
# UK           64.511   2950039        242495  0.907    Europe
# US          318.523  17348075       9525067  0.915   America

# %%
## for COlumn-wise, use simple indexing like that of list 
df["Population"]
# Out:
# Canada      35.467
# France      63.951
# Germany     80.940
# Italy       60.665
# Japan      127.061
# UK          64.511
# US         318.523
# Name: Population, dtype: float64

# %% [markdown]
# ## Axis and Drop

# %%
df = pd.DataFrame({
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
})

# %%
df
# Out:
#    Population       GDP  Surface Area    HDI Continent
# 0      35.467   1785387       9984670  0.913   America
# 1      63.951   2833687        640679  0.888    Europe
# 2      80.940   3874437        357114  0.916    Europe
# 3      60.665   2167744        301336  0.873    Europe
# 4     127.061   4602367        377930  0.891      Asia
# 5      64.511   2950039        242495  0.907    Europe
# 6     318.523  17348075       9525067  0.915   America

# %% [markdown]
# row-wise index =>  axis=0
#
# columns        =>  axis =1

# %%
df.drop(4,axis=0)
# Out:
#    Population       GDP  Surface Area    HDI Continent
# 0      35.467   1785387       9984670  0.913   America
# 1      63.951   2833687        640679  0.888    Europe
# 2      80.940   3874437        357114  0.916    Europe
# 3      60.665   2167744        301336  0.873    Europe
# 5      64.511   2950039        242495  0.907    Europe
# 6     318.523  17348075       9525067  0.915   America

# %%
df.drop(["Population"], axis=1)
# Out:
#         GDP  Surface Area    HDI Continent
# 0   1785387       9984670  0.913   America
# 1   2833687        640679  0.888    Europe
# 2   3874437        357114  0.916    Europe
# 3   2167744        301336  0.873    Europe
# 4   4602367        377930  0.891      Asia
# 5   2950039        242495  0.907    Europe
# 6  17348075       9525067  0.915   America

# %% [markdown]
# ## Load CSV
#
#     - Place the file where your jupyter notebook is already present
#     - Copy it's path and make sure to change the direction of Slash from \ to this /
#     - If you are copying from some complex path, write "r" before the quotation marks of Path

# %%
data = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
data
# Out:
#       Index  Age Attrition     BusinessTravel  DailyRate  \
# 0         1   41       Yes      Travel_Rarely       1102
# 1         2   49        No  Travel_Frequently        279
# 2         3   37       Yes      Travel_Rarely       1373
# 3         4   33        No  Travel_Frequently       1392
# 4         5   27        No      Travel_Rarely        591
# ...     ...  ...       ...                ...        ...
# 1465   1466   36        No  Travel_Frequently        884
# 1466   1467   39        No      Travel_Rarely        613
# 1467   1468   27        No      Travel_Rarely        155
# 1468   1469   49        No  Travel_Frequently       1023
# 1469   1470   34        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# ...

# %% [markdown]
# ## Drop the index column

# %%
data.drop(["Index"],axis=1,inplace=True)

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ### Fetch top or last rows

# %% [markdown]
# For top Rows:  head()
#
# For last Rows: tail()

# %%
data.head()   #by default
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.head()  ## Like Limit in SQL
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.tail(2)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 1468               2               9                  6
# ...

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ## info
# for Data or table structure

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ## Description

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
data.describe(include="object")
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %% [markdown]
# ### Duplicates and Missing values

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
data.duplicated().sum()    #sum or add up all the true values
# Out:
# 0

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data["Attrition"]
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object

# %%
data["Attrition"].duplicated()
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 1465     True
# 1466     True
# 1467     True
# 1468     True
# 1469     True
# Name: Attrition, Length: 1470, dtype: bool

# %%
data["Attrition"].duplicated().sum()
# Out:
# 1468

# %%
1470-1468
# Out:
# 2

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# 65% scenarios = > you have to remove the duplicates from the whole complete data (row-wise exactly same)
#
# 35% scenarios => you have to keep the duplicates

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.isnull()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ## Save the updated file

# %%
data.to_csv("New_file.csv",index=False)

# %%
df = pd.read_csv("New_file.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ## Happy Learning!!
